# %%
# Import library mortapy
import mortapy as mp

# Tentukan parameter dasar yang akan sering kita gunakan
usia_awal = 60
suku_bunga = 0.06 # 6%
gender_pilihan = 'wanita'

print("="*50)
print(f"KALKULASI AKTUARIA DENGAN TAMPILAN LATEX")
print("="*50)
print(f"Parameter Umum: Usia = {usia_awal}, Gender = {gender_pilihan}, Suku Bunga = {suku_bunga*100:.2f}%")
print("-"*50)

# 1. Menghitung Premi Tunggal Bersih (NSP) untuk Asuransi Jiwa Seumur Hidup
print("\n--- PREMI TUNGGAL BERSIH (WHOLE LIFE) ---")
nsp_result = mp.calculate_whole_life_nsp(
    age=usia_awal,
    interest_rate=suku_bunga,
    gender=gender_pilihan
)
# Tampilkan hasil (Jupyter akan otomatis memanggil _repr_latex_())
nsp_result
# Out:
# ...
# KALKULASI AKTUARIA DENGAN TAMPILAN LATEX
# ...
# Parameter Umum: Usia = 60, Gender = wanita, Suku Bunga = 6.00%
# --------------------------------------------------
#
# --- PREMI TUNGGAL BERSIH (WHOLE LIFE) ---
# Formula: A_{60}
# Hasil: 0.28860079

# %%
# Lanjutan dari sel sebelumnya...

# 2. Menghitung Nilai Sekarang (PV) dari Anuitas Jiwa Seumur Hidup Awal Tahun
print("\n--- ANUITAS JIWA SEUMUR HIDUP AWAL TAHUN ---")
pv_anuitas_result = mp.calculate_whole_life_annuity_pv(
    age=usia_awal,
    interest_rate=suku_bunga,
    gender=gender_pilihan
)

# Tampilkan hasil
pv_anuitas_result
# Out:
# --- ANUITAS JIWA SEUMUR HIDUP AWAL TAHUN ---
# Formula: \ddot{a}_{60}
# Hasil: 12.56805268
